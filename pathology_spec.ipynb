dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice156-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice114.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice096.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice153.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice090.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice066.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice094.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice144-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice129-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice120-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice128-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice020.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice180.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice078.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice047.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice204.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice168.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice041-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice158.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice111.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice027.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice152.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice190.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice115.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice206.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice196-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice070-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice051.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice196.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice003.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice063.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice075.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice028.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice208-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice169.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice136.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice203-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice139.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice025.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice107.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice003-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice017-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice197.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice136.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice108-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice089.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice067.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice033-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice184.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice140.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice031-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice104.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice075-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice039.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice130.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice167.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice127-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice071.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice140.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice083.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice017.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice150.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice103.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice147-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice001.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice061.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice015.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice046.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice204-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice087-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice069.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice088.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice018-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice150.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice061-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice118.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice008.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice039.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice095-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice191.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice110-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice127.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice093.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice041.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice175.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice198.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice195.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice118-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice059.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice146.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice163.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice073.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice176-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice013.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice064-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice088.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice155.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice058.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice194-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice044-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice115-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice082.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice106.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice116.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice203.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice182.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice144.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice076.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice150-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice091.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice049.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice042.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice112.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice069-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice036.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice160.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice169-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice042.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice072-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice074.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice011.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice086.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice036.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice121.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice139.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice019.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice089.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice161.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice003.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice027-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice073.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice201.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice147.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice096-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice093-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice184-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice019.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice056.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice024.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice133-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice149.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice206.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice091.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice125.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice117.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice053-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice005-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice138.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice073.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice188.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice016.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice120.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice182.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice093.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice201-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice022.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice162-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice062.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice048.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice082-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice183.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice142-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice026.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice015-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice193.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice065.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice180.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice013.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice098.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice094.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice187.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice073-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice141.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice208.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice007-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice047.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice159-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice170.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice141.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice023.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice021-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice045.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice017.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice145.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice124.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice203.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice120.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice161-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice023.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice156.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice198.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice067.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice072.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice105.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice045.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice011.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice167-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice063.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice048-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice174.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice199.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice199.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice078.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice099.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice121.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice119-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice030-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice090.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice026.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice130-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice197.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice127.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice198-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice075.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice052.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice127.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice135.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice107-info.txt
#  extracting: voice-icar-federico-ii-database-1.0.0/voice052.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice108.dat
#  extracting: voice-icar-federico-ii-database-1.0.0/voice005.hea
#  extracting: voice-icar-federico-ii-database-1.0.0/voice183-info.txt

# %%
voice_1 = wfdb.rdrecord('/content/voice-icar-federico-ii-database-1.0.0/voice004')
#wfdb.plot_wfdb(record=voice_1)
#display(voice_1.__dict__)
segment = voice_1.p_signal
segment = segment[:,0]
time = np.arange(0,len(segment))/(voice_1.fs)
plt.figure(figsize=(15,4))
plt.plot(time, segment)
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pre_emph_coeff = 0.90
emphasized_signal = np.append(segment[0], segment[1:] - pre_emph_coeff * segment[:-1])
new_time = np.arange(0, len(emphasized_signal))/(voice_1.fs)
plt.figure(figsize=(15,4))
plt.plot(new_time, emphasized_signal)
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Frames for conversion of transforms

# %%
frame_size = 0.025
frame_stride = 0.01
frame_length, frame_step = frame_size * (voice_1.fs), frame_stride * (voice_1.fs)
signal_length = len(emphasized_signal)
frame_length = int(round(frame_length))
frame_step = int(round(frame_step))
num_frames = int(np.ceil(float(np.abs(signal_length - frame_length)) / frame_step))

pad_signal_length = num_frames * frame_step + frame_length
z = np.zeros((pad_signal_length - signal_length))
pad_signal = np.append(emphasized_signal, z)

indices = np.tile(np.arange(0, frame_length), (num_frames, 1)) + np.tile(np.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
frames = pad_signal[indices.astype(np.int32, copy=False)]

# %%
# passing each frame through hamming window
frames *= np.hamming(frame_length)

# %%
frames.shape
# Out:
# (474, 200)

# %% [markdown]
# ### Mel Filter Bank

# %%
melfb = lb.filters.mel(sr = voice_1.fs, n_fft=1024, fmax=8000)
# Out:
# <ipython-input-9-8da10575aaa1>:1: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   melfb = lb.filters.mel(sr = voice_1.fs, n_fft=1024, fmax=8000)

# %%
fig, ax = plt.subplots()
img = lb.display.specshow(melfb, x_axis='linear', ax=ax)
ax.set(ylabel='Mel filter', title='Mel filter bank')
fig.colorbar(img, ax=ax)

# %% [markdown]
# ### Mel Spectogram

# %%
mels = lb.feature.melspectrogram(y=segment, sr=voice_1.fs, n_mels=1024, fmax=8000)
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/feature/spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)

# %%
mels_db = lb.power_to_db(mels, ref=np.max)

# %%
fig, ax = plt.subplots()
img = lb.display.specshow(mels_db, x_axis = 'time', y_axis='mel', sr=voice_1.fs, fmax=voice_1.fs/2, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')
# Out:
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]

# %% [markdown]
# ### MFCC

# %%
mfcc = lb.feature.mfcc(y=segment, sr=voice_1.fs, n_mfcc=13)

# %%
fig, ax = plt.subplots()
img = lb.display.specshow(mfcc, x_axis='time')
ax.set(title='MFCC')
fig.colorbar(img, ax=ax)

# %% [markdown]
# ### Chirplet Transform

# %%
chirplet = lb.cqt(segment)

# %%
plt.figure()
plt.plot(chirplet)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
frequencies = lb.cqt_frequencies(n_bins=512, fmin = 0)


plt.figure(figsize=(10, 5))
lb.display.specshow(np.abs(chirplet), x_axis="time", y_axis="cqt_hz")
plt.title("Chirplet Transform Spectrogram")
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency (Hz)")
plt.colorbar()
plt.show()

# %% [markdown]
# ### Fourier Transform

# %%
fourier = lb.stft(segment, n_fft=1024, hop_length=256)  # STFT of y
S_db = lb.amplitude_to_db(np.abs(fourier), ref=np.max)

# %%
plt.figure()
lb.display.specshow(S_db, x_axis="time", y_axis="fft")
plt.colorbar()

# %% [markdown]
# ###
